# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("insurance.csv")
df.head
# Out:
# <bound method NDFrame.head of     age  bought_insurance
# 0    56                 0
# 1    69                 1
# 2    46                 0
# 3    32                 0
# 4    60                 1
# 5    25                 0
# 6    38                 0
# 7    56                 1
# 8    36                 0
# 9    40                 1
# 10   28                 0
# 11   28                 0
# 12   41                 0
# 13   70                 1
# 14   53                 1
# 15   57                 1
# 16   41                 1
# 17   20                 0
# 18   39                 0
# 19   70                 1
# 20   19                 0
# 21   41                 0
# 22   61                 1
# 23   47                 1
# 24   55                 1
# 25   19                 0
# 26   38                 0
# 27   50                 1
# 28   29                 0
# 29   39                 0
# 30   61                 1
# 31   42                 1
# 32   66                 1
# 33   44                 1
# 34   59                 1
# 35   45                 1
# 36   33                 0
# 37   32                 0
# 38   64                 1
# 39   68                 1
# 40   61                 1
# 41   69                 1
# 42   20                 0
# 43   54                 1
# 44   68                 1
# 45   24                 0
# 46   38                 1
# 47   26                 0
# 48   56                 1
# 49   35                 0>

# %%
plt.scatter(df.age,df.bought_insurance,marker='+',color='red')

# %%
from sklearn.model_selection import train_test_split

# %%
train_test_split(df[['age']], df.bought_insurance, train_size=0.9)
# Out:
# [    age
#  9    40
#  44   68
#  3    32
#  7    56
#  0    56
#  34   59
#  8    36
#  15   57
#  45   24
#  29   39
#  42   20
#  36   33
#  32   66
#  38   64
#  16   41
#  11   28
#  10   28
#  22   61
#  30   61
#  43   54
#  46   38
#  24   55
#  40   61
#  48   56
#  17   20
#  1    69
#  25   19
#  31   42
#  26   38
#  13   70
#  39   68
#  2    46
#  23   47
#  6    38
#  18   39
#  27   50
#  12   41
#  37   32
#  41   69
#  28   29
#  19   70
#  47   26
#  33   44
#  14   53
#  20   19,
#      age
#  49   35
#  35   45
#  5    25
#  21   41
#  4    60,
#  9     1
#  44    1
#  3     0
#  7     1
#  0     0
#  34    1
#  8     0
#  15    1
#  45    0
#  29    0
#  42    0
#  36    0
#  32    1
#  38    1
#  16    1
#  11    0
#  10    0
#  22    1
#  30    1
#  43    1
#  46    1
#  24    1
#  40    1
#  48    1
#  17    0
#  1     1
#  25    0
#  31    1
#  26    0
#  13    1
#  39    1
#  2     0
#  23    1
#  6     0
#  18    0
#  27    1
#  12    0
#  37    0
#  41    1
#  28    0
#  19    1
#  47    0
#  33    1
#  14    1
#  20    0
#  Name: bought_insurance, dtype: int64,
#  49    0
#  35    1
#  5     0
#  21    0
#  4     1
#  Name: bought_insurance, dtype: int64]

# %%
x_train, x_test, y_train, y_test = train_test_split(df[['age']],df.bought_insurance,test_size=0.1)

# %%
x_test
# Out:
#     age
# 28   29
# 7    56
# 12   41
# 49   35
# 30   61

# %%
x_train
# Out:
#     age
# 46   38
# 26   38
# 48   56
# 8    36
# 47   26
# 45   24
# 11   28
# 29   39
# 24   55
# 9    40
# 33   44
# 1    69
# 14   53
# 15   57
# 18   39
# 19   70
# 42   20
# 2    46
# 39   68
# 10   28
# 4    60
# 32   66
# 22   61
# 13   70
# 25   19
# 16   41
# 34   59
# 21   41
# 41   69
# 31   42
# 27   50
# 37   32
# 5    25
# 17   20
# 0    56
# 43   54
# 44   68
# 38   64
# 23   47
# 3    32
# 35   45
# 40   61
# 6    38
# 20   19
# 36   33

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
model.predict(x_test)
# Out:
# array([0, 1, 0, 0, 1])

# %%
model.score(x_test,y_test)
# Out:
# 1.0

# %%
model.predict_proba(x_test)
# Out:
# array([[0.95126143, 0.04873857],
#        [0.04336725, 0.95663275],
#        [0.56850345, 0.43149655],
#        [0.8352818 , 0.1647182 ],
#        [0.01453049, 0.98546951]])

# %%
model.predict([[80]])
# Out:
# D:\ML course\Model buildin\.venv\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])
